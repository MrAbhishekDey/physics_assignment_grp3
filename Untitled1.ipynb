# %% [markdown]
# <a href="https://colab.research.google.com/github/MrAbhishekDey/physics_assignment_grp3/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Welcome to Python Programming!\nI am learning the basics.")
# Out:
# Welcome to Python Programming!
# I am learning the basics.

# %%
Name='pranto'
Age=22
print("My name is pranto and I am 22 years old.")
# Out:
# My name is pranto and I am 22 years old.

# %%
name='pranto'
lan='python'
print("hello",name,",your favorite language is",lan )
# Out:
# hello pranto ,your favorite language is python

# %%
num1=input('enter first num: ')
num2=input('enter second num: ')
num1=int(num1)
num2=int(num2)
print("the sum is:",num1+num2)
# Out:
# enter first num: 20
# enter second num: 10
# the sum is: 30

# %%
num1=int(input('enter first num:'))
num2=int(input('enter second num:'))
print("addition=" ,num1+num2)
print("subtraction=",num1-num2)
print("multiplication=",num1*num2)
# Out:
# enter first num:15
# enter second num:5
# addition= 20
# subtraction= 10
# multiplication= 75
